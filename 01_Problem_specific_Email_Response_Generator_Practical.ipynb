# %%
pip install ollama streamlit nest_asyncio pyngrok
# Out:
# Requirement already satisfied: ollama in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (0.6.2)
# Requirement already satisfied: streamlit in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (1.63.0)
# Requirement already satisfied: nest_asyncio in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (1.6.0)
# Requirement already satisfied: pyngrok in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (8.1.2)
# Requirement already satisfied: httpx>=0.27 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from ollama) (2.13.5)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=5.0.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: numpy<3,>=1.23 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (2.5.3)
# Requirement already satisfied: packaging>=20 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (26.3)
# Requirement already satisfied: pandas<4,>=1.4.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (3.0.5)
# Requirement already satisfied: pillow<13,>=7.1.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=5.26.1 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (7.36.1)
# Requirement already satisfied: pyarrow!=25.0.0,<26,>=7.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (25.0.1)
# Requirement already satisfied: requests<3,>=2.27 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette<2,>=0.46.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (1.6.0)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (0.52.4)
# Requirement already satisfied: httptools<1,>=0.6.3 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio<5,>=4.0.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (4.15.1)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets<17,>=12.0.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (16.1.1)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: PyYAML>=5.1 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: jinja2 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2.26.0)
# Requirement already satisfied: idna>=2.8 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from anyio<5,>=4.0.0->streamlit) (3.19)
# Requirement already satisfied: certifi in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from httpx>=0.27->ollama) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from pydantic>=2.9->ollama) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from pydantic>=2.9->ollama) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from pydantic>=2.9->ollama) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in d:\local-genai-prompt-optimization-pso\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ollama
import nest_asyncio

# %%
# Hey Jupyter kernel, behave nicely if someone tries to start another async loop inside you.
# manage clashes of the kernal, when streamlit is running
# event loop management
nest_asyncio.apply()

# %%
def analyze_customer_email(email: str) -> str:
    """
    Step 1: Analyze and extract key info (intent, order number, sentiment, etc.)
    """
    extract_prompt = f"""
    Analyze the following customer email.
    1. Classify the intent (refund request, delivery status, product inquiry, complaint, etc.)
    2. Extract key details such as order number, product, sentiment, urgency.
    3. Return the result as JSON with keys: intent, order_number, product, sentiment, urgency, summary.

    Customer Email:
    {email}
    """
    response = ollama.chat(
        model="llama3.2:1b",
        messages=[{"role": "user", "content": extract_prompt}]
    )
    return response['message']['content']

# %%
def draft_reply(email: str, analysis: str) -> str:
    """
    Step 2: Generate support reply with empathy, professionalism, and business alignment
    """
    business_context = """
    You are a professional customer support representative at a consumer electronics company. 
    Always:
    - Be polite, empathetic, and concise. 
    - Acknowledge the customer situation.
    - Include relevant details (order info, delivery timing, etc.) when available.
    - End positively, reassuring the customer that we value them.
    """

    reply_prompt = f"""
    {business_context}

    The customer sent the following email:
    {email}

    Analysis of their message:
    {analysis}

    Draft a polite, appropriate email response:
    """
# "role": "user" means: treat this as if it came from the “user” in a chat.
    response = ollama.chat(
        model="llama3.2:1b",
        messages=[{"role": "user", "content": reply_prompt}]
    )
    return response['message']['content']
# =====================================
# 4️⃣ Test the pipeline directly (without UI)
# =====================================
customer_email = """
Hi Support,
I ordered a Bluetooth speaker last week (Order #12345), but it still hasn’t arrived. 
Can you please tell me when it will be delivered? I needed it for a birthday gift.
"""

analysis = analyze_customer_email(customer_email)
reply = draft_reply(customer_email, analysis)

print("🔍 Extracted Understanding:\n", analysis, "\n")
print("✉️ Draft Reply:\n", reply)
# Out:
# 🔍 Extracted Understanding:
#  Here's the analysis of the customer email:
#
# 1. **Intent**: The intent of the customer is to inquire about the delivery status of their Bluetooth speaker order.
#
# 2. **Key Details**:
#     * Order Number: 12345
#     * Product: Bluetooth speaker
#     * Sentiment: Negative (the customer is frustrated and disappointed about the delay)
#     * Urgency: High (the customer is worried about receiving the gift on time for a birthday)
#
# 3. **Summary (JSON output)**:
#
# ```json
# {
#   "intent": "Delivery Status Inquiry",
#   "order_number": 12345,
#   "product": "Bluetooth speaker",
#   "sentiment": "Negative",
#   "urgency": "High",
#   "summary": "Order for a birthday gift, still waiting for delivery"
# }
# ```
#
# Note: The summary is a placeholder for a more detailed summary that could include the customer's preferred delivery date, any additional information required by the customer, or any relevant additional context.
#
# ✉️ Draft Reply:
#  Here's a polite and concise email response:
#
# Subject: Re: Delivery Status Inquiry for Order #12345
#
# Dear [Customer's Name],
#
# Thank you for reaching out to us regarding your concern about the delivery status of your Bluetooth speaker order (Order #12345). We apologize for the delay and appreciate your patience.
#
# We're currently working on processing the order, and we expect to dispatch it out on [Proposed Delivery Date]. We understand how important it is to receive your gift on time for the birthday, and we're doing our best to expedite the delivery.
#
# We'll send you an update on the status of your order via email once it's dispatched. If you have any further questions or concerns, please don't hesitate to contact us.
#
# Thank you for your understanding, and we hope you receive the gift on time.
#
# Best regards,
#
# [Your Name]
# Customer Support Representative
# [Consumer Electronics Company Name]

# %%
# %%writefile support_ai_app.py
import streamlit as st
import ollama

def analyze_customer_email(email: str) -> str:
    extract_prompt = f"""
    Analyze the following customer email.
    1. Classify the intent (refund request, delivery status, product inquiry, complaint, etc.)
    2. Extract key details such as order number, product, sentiment, urgency.
    3. Return the result as JSON with keys: intent, order_number, product, sentiment, urgency, summary.

    Customer Email:
    {email}
    """
    response = ollama.chat(
        model="llama3.2:1b",
        messages=[{"role": "user", "content": extract_prompt}]
    )
    return response['message']['content']


def draft_reply(email: str, analysis: str) -> str:
    business_context = """
    You are a professional customer support representative at a consumer electronics company.
    Always:
    - Be polite, empathetic, and concise.
    - Acknowledge the customer situation.
    - Include relevant details (order info, delivery timing, etc.) when available.
    - End positively, reassuring the customer that we value them.
    """

    reply_prompt = f"""
    {business_context}

    The customer sent the following email:
    {email}

    Analysis of their message:
    {analysis}

    Draft a polite, appropriate email response:
    """

    response = ollama.chat(
        model="llama3.2:1b",
        messages=[{"role": "user", "content": reply_prompt}]
    )
    return response['message']['content']


# ------------------ UI -------------------------
st.set_page_config(page_title="AI Customer Support Assistant", page_icon="📩")

st.title("📩 AI-Powered Customer Support Assistant")
st.write("Paste a customer email and let AI analyze and draft a polite, professional reply.")

# Input from user
customer_email = st.text_area("Customer Email:", height=200, placeholder="Paste the customer email here...")

if st.button("Generate Reply"):
    if customer_email.strip():
        with st.spinner("🔍 Analyzing email..."):
            analysis = analyze_customer_email(customer_email)
        st.subheader("Extracted Understanding")
        st.json(analysis)

        with st.spinner("✍️ Drafting reply..."):
            reply = draft_reply(customer_email, analysis)

        st.subheader("AI Drafted Reply")
        st.write(reply)
    else:
        st.warning("Please paste a customer email first.")
# Out:
# Writing support_ai_app.py

# %%
# !streamlit run support_ai_app.py

# %%
##!streamlit run support_ai_app.py --server.headless true --server.port 8501
